# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv('data.csv')
a
# Out:
#      Unnamed: 0        Brand                            Model  AccelSec  \
# 0             0       Tesla     Model 3 Long Range Dual Motor       4.6
# 1             1  Volkswagen                         ID.3 Pure      10.0
# 2             2    Polestar                                 2       4.7
# 3             3         BMW                              iX3        6.8
# 4             4       Honda                                e        9.5
# ..          ...          ...                              ...       ...
# 98           98      Nissan                       Ariya 63kWh       7.5
# 99           99        Audi     e-tron S Sportback 55 quattro       4.5
# 100         100      Nissan               Ariya e-4ORCE 63kWh       5.9
# 101         101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1
# 102         102       Byton                 M-Byte 95 kWh 2WD       7.5
#
#      TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# ...

# %% [markdown]
# # Null values

# %%
a.isnull().sum()
# Out:
# Unnamed: 0         0
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %% [markdown]
# # Top first 5 row

# %%
a.head()
# Out:
#    Unnamed: 0        Brand                          Model  AccelSec  \
# 0           0       Tesla   Model 3 Long Range Dual Motor       4.6
# 1           1  Volkswagen                       ID.3 Pure      10.0
# 2           2    Polestar                               2       4.7
# 3           3         BMW                            iX3        6.8
# 4           4       Honda                              e        9.5
#
#    TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0           233       450              161             940         Yes
# 1           160       270              167             250          No
# 2           210       400              181             620         Yes
# 3           180       360              206             560         Yes
# 4           145       170              168             190         Yes
#
#   PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro
# 0        AWD  Type 2 CCS      Sedan       D      5      55480
# ...

# %% [markdown]
# # Top last 5 row

# %%
a.tail()
# Out:
#      Unnamed: 0    Brand                            Model  AccelSec  \
# 98           98  Nissan                       Ariya 63kWh       7.5
# 99           99    Audi     e-tron S Sportback 55 quattro       4.5
# 100         100  Nissan               Ariya e-4ORCE 63kWh       5.9
# 101         101  Nissan   Ariya e-4ORCE 87kWh Performance       5.1
# 102         102   Byton                 M-Byte 95 kWh 2WD       7.5
#
#      TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 98            160       330              191             440         Yes
# 99            210       335              258             540         Yes
# 100           200       325              194             440         Yes
# 101           200       375              232             450         Yes
# 102           190       400              238             480          No
#
#     PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro
# ...

# %% [markdown]
# # Data types

# %%
a.dtypes
# Out:
# Unnamed: 0           int64
# Brand               object
# Model               object
# AccelSec           float64
# TopSpeed_KmH         int64
# Range_Km             int64
# Efficiency_WhKm      int64
# FastCharge_KmH       int64
# RapidCharge         object
# PowerTrain          object
# PlugType            object
# BodyStyle           object
# Segment             object
# Seats                int64
# PriceEuro            int64
# dtype: object

# %% [markdown]
# # Delete unwanted columns

# %%
df=a.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
df.isnull().sum()
# Out:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
plt.figure(figsize=(12, 6))
sns.barplot(x='Brand', y='PriceEuro', data=df, ci=None)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.title('Price vs. Brand')
plt.xlabel('Brand')
plt.ylabel('Price (Euro)')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10872\1972963966.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Brand', y='PriceEuro', data=df, ci=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
plt.figure(figsize=(12, 8))
sns.scatterplot(x='PriceEuro', y='Model', hue='Model', data=df, palette='tab20', s=100)
plt.title('Price vs. Model')
plt.xlabel('Price (Euro)')
plt.ylabel('Model')
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select relevant columns
data_subset = df[['TopSpeed_KmH', 'Brand', 'Model']]

# Create a pivot table using mean as an aggregation function
pivot_data = data_subset.pivot_table(index='Brand', columns='Model', values='TopSpeed_KmH', aggfunc='mean')

# Plotting the grouped bar plot
plt.figure(figsize=(14, 8))
pivot_data.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Top Speed vs. Brand and Model')
plt.xlabel('Brand')
plt.ylabel('Top Speed (Km/H)')
plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
g = sns.FacetGrid(df, col='BodyStyle', col_wrap=3, height=5, sharex=False)
g.map(plt.hist, 'PriceEuro', bins=20, color='skyblue')
g.set_axis_labels('Price (Euro)', 'Frequency')
g.set_titles(col_template="{col_name}")
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is named 'df'
df_encoded = df.copy()

# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Apply label encoding for categorical columns
label_encoder = LabelEncoder()
for column in categorical_columns:
    df_encoded[column] = label_encoder.fit_transform(df[column])

# Display the encoded DataFrame
print(df_encoded)
# Out:
#      Brand  Model  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0       30     46       4.6           233       450              161
# 1       31     33      10.0           160       270              167
# 2       23      0       4.7           210       400              181
# 3        2    101       6.8           180       360              206
# 4        9     78       9.5           145       170              168
# ..     ...    ...       ...           ...       ...              ...
# 98      20      6       7.5           160       330              191
# 99       1     94       4.5           210       335              258
# 100     20      8       5.9           200       325              194
# 101     20     10       5.1           200       375              232
# 102      3     42       7.5           190       400              238
#
#      FastCharge_KmH  RapidCharge  PowerTrain  PlugType  BodyStyle  Segment  \
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df_encoded'
# Selecting relevant columns
X = df_encoded[['PriceEuro', 'Model']]  # Assuming 'Model_encoded' is the encoded version of 'Model'

# Defining the number of clusters (you can adjust this based on your preference)
n_clusters = 5

# Creating and fitting the KMeans model
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
y_kmeans = kmeans.fit_predict(X)

# Adding cluster labels to the original DataFrame
df_encoded['Cluster'] = y_kmeans

# Plotting the clusters
plt.figure(figsize=(15, 7))

# Scatter plot for each cluster
for cluster_label in range(n_clusters):
    sns.scatterplot(x=df_encoded[df_encoded['Cluster'] == cluster_label]['PriceEuro'],
                    y=df_encoded[df_encoded['Cluster'] == cluster_label]['Model'],
                    label=f'Cluster {cluster_label + 1}', s=50)

# Add cluster centers
cluster_centers = kmeans.cluster_centers_
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='black', marker='x', s=100, label='Centroids')

plt.title('K-means Clustering based on Price and Model')
plt.xlabel('Price (Euro)')
plt.ylabel('Model')
plt.legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
